# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


print("python version: "+sys.version)
print("pandas version: "+pd.__version__)
print("numpy version: "+np.__version__)
#print("matplotlib version: "+plt.__version__)
print("seaborn version: "+sns.__version__)
# Out:
# python version: 3.13.7 (main, Aug 15 2025, 12:34:02) [GCC 15.2.1 20250813]
# pandas version: 2.3.1
# numpy version: 2.3.3
# seaborn version: 0.13.2

# %%
data = 'wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/course_lead_scoring.csv'

# %%
# !wget $data -O data-homework-3.csv

# %%
df = pd.read_csv('data-homework-3.csv')
df.head()
# Out:
#     lead_source    industry  number_of_courses_viewed  annual_income  \
# 0      paid_ads         NaN                         1        79450.0
# 1  social_media      retail                         1        46992.0
# 2        events  healthcare                         5        78796.0
# 3      paid_ads      retail                         2        83843.0
# 4      referral   education                         3        85012.0
#
#   employment_status       location  interaction_count  lead_score  converted
# 0        unemployed  south_america                  4        0.94          1
# 1          employed  south_america                  1        0.80          0
# 2        unemployed      australia                  3        0.69          1
# 3               NaN      australia                  1        0.87          0
# 4     self_employed         europe                  3        0.62          1

# %%
df.dtypes
# Out:
# lead_source                  object
# industry                     object
# number_of_courses_viewed      int64
# annual_income               float64
# employment_status            object
# location                     object
# interaction_count             int64
# lead_score                  float64
# converted                     int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# lead_source                 128
# industry                    134
# number_of_courses_viewed      0
# annual_income               181
# employment_status           100
# location                     63
# interaction_count             0
# lead_score                    0
# converted                     0
# dtype: int64

# %%
categorical_columns = list(df.dtypes[df.dtypes == 'object'].index)
categorical_columns
# Out:
# ['lead_source', 'industry', 'employment_status', 'location']

# %%
categorical = ['lead_source', 'industry', 'employment_status', 'location']

# %%
numerical_columns = list(df.dtypes[df.dtypes != 'object'].index)
numerical_columns
# Out:
# ['number_of_courses_viewed',
#  'annual_income',
#  'interaction_count',
#  'lead_score',
#  'converted']

# %%
numerical = ['number_of_courses_viewed', 'annual_income', 'interaction_count', 'lead_score', 'converted']
numerical_without_converted = ['number_of_courses_viewed', 'annual_income', 'interaction_count', 'lead_score']

# %%
df[categorical].isnull().sum()
# Out:
# lead_source          128
# industry             134
# employment_status    100
# location              63
# dtype: int64

# %%
df[numerical].isnull().sum()
# Out:
# number_of_courses_viewed      0
# annual_income               181
# interaction_count             0
# lead_score                    0
# converted                     0
# dtype: int64

# %%
df[numerical_without_converted].isnull().sum()
# Out:
# number_of_courses_viewed      0
# annual_income               181
# interaction_count             0
# lead_score                    0
# dtype: int64

# %%
df[categorical].nunique()
# Out:
# lead_source          5
# industry             7
# employment_status    4
# location             7
# dtype: int64

# %%
df[numerical].nunique()
# Out:
# number_of_courses_viewed      10
# annual_income               1267
# interaction_count             12
# lead_score                   101
# converted                      2
# dtype: int64

# %%
df.lead_source = df.lead_source.fillna('NA')
df.industry = df.industry.fillna('NA')
df.employment_status = df.employment_status.fillna('NA')
df.location = df.location.fillna('NA')
df.annual_income  = df.annual_income.fillna(0)

# %%
df[numerical].isnull().sum()
# Out:
# number_of_courses_viewed    0
# annual_income               0
# interaction_count           0
# lead_score                  0
# converted                   0
# dtype: int64

# %%
df[numerical_without_converted].isnull().sum()
# Out:
# number_of_courses_viewed    0
# annual_income               0
# interaction_count           0
# lead_score                  0
# dtype: int64

# %%
df[categorical].isnull().sum()
# Out:
# lead_source          0
# industry             0
# employment_status    0
# location             0
# dtype: int64

# %%
# Q1 
# What is the most frequent observation (mode) for the column industry?

df.industry.value_counts()
# Out:
# industry
# retail           203
# finance          200
# other            198
# healthcare       187
# education        187
# technology       179
# manufacturing    174
# NA               134
# Name: count, dtype: int64

# %%
# Q2
# Biggest correlation (1 point) 

from sklearn.model_selection import train_test_split
from sklearn.metrics import mutual_info_score


df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42)
df_full_val = df_val

# %%
df_full_train = df_full_train.reset_index(drop=True)

# %%
df_full_train
# Out:
#        lead_source       industry  number_of_courses_viewed  annual_income  \
# 0     social_media  manufacturing                         2        44403.0
# 1           events         retail                         3        38048.0
# 2     social_media      education                         2        71399.0
# 3         referral      education                         2        47912.0
# 4         paid_ads     healthcare                         1        34806.0
# ...            ...            ...                       ...            ...
# 1164        events  manufacturing                         1        57039.0
# 1165        events     healthcare                         2        56185.0
# 1166      paid_ads  manufacturing                         1        56402.0
# 1167      paid_ads     technology                         1        45688.0
# 1168        events  manufacturing                         0        43862.0
#
#      employment_status       location  interaction_count  lead_score  \
# 0        self_employed      australia                  1        0.71
# 1              student  north_america                  6        0.97
# 2                   NA         europe                  1        0.51
# 3             employed      australia                  1        0.04
# 4             employed         europe                  4        0.32
# ...                ...            ...                ...         ...
# 1164          employed  south_america                  2        0.30
# 1165           student  south_america                  2        0.44
# 1166           student  north_america                  1        0.02
# 1167           student  north_america                  3        0.02
# 1168     self_employed           asia                  4        0.21
#
#       converted
# 0             0
# 1             1
# 2             1
# 3             0
# 4             1
# ...         ...
# 1164          0
# 1165          0
# 1166          0
# 1167          1
# 1168          0
#
# [1169 rows x 9 columns]

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (876, 293, 293)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_full_train.values
y_val = df_full_val.values
y_test = df_test.values


y_train_interaction_count = df_train.interaction_count.values
y_val_interaction_count = df_val.interaction_count.values
y_test_interaction_count = df_test.interaction_count.values

del df_train['interaction_count']
del df_val['interaction_count']
del df_test['interaction_count']

y_train_lead_score = df_train.lead_score.values
y_val_lead_score = df_val.lead_score.values
y_test_lead_score = df_test.lead_score.values

del df_train['lead_score']
del df_val['lead_score']
del df_test['lead_score']

y_train_annual_income = df_train.annual_income.values
y_val_annual_income = df_val.annual_income.values
y_test_annual_income = df_test.annual_income.values

del df_train['annual_income']
del df_val['annual_income']
del df_test['annual_income']

y_train_number_of_courses_viewed = df_train.number_of_courses_viewed.values
y_val_number_of_courses_viewed = df_val.number_of_courses_viewed.values
y_test_number_of_courses_viewed = df_test.number_of_courses_viewed.values

del df_train['number_of_courses_viewed']
del df_val['number_of_courses_viewed']
del df_test['number_of_courses_viewed']

# %%
print("Max value for number_of_courses_viewed: ",df_full_train.number_of_courses_viewed.max())
print("Max value for annual_income: ",df_full_train.annual_income.max())
print("Max value for interaction_count: ",df_full_train.interaction_count.max())
print("Max value for lead_score: ",df_full_train.lead_score.max())
# Out:
# Max value for number_of_courses_viewed:  8
# Max value for annual_income:  109899.0
# Max value for interaction_count:  11
# Max value for lead_score:  1.0

# %%
df_full_train
# Out:
#        lead_source       industry  number_of_courses_viewed  annual_income  \
# 0     social_media  manufacturing                         2        44403.0
# 1           events         retail                         3        38048.0
# 2     social_media      education                         2        71399.0
# 3         referral      education                         2        47912.0
# 4         paid_ads     healthcare                         1        34806.0
# ...            ...            ...                       ...            ...
# 1164        events  manufacturing                         1        57039.0
# 1165        events     healthcare                         2        56185.0
# 1166      paid_ads  manufacturing                         1        56402.0
# 1167      paid_ads     technology                         1        45688.0
# 1168        events  manufacturing                         0        43862.0
#
#      employment_status       location  interaction_count  lead_score  \
# 0        self_employed      australia                  1        0.71
# 1              student  north_america                  6        0.97
# 2                   NA         europe                  1        0.51
# 3             employed      australia                  1        0.04
# 4             employed         europe                  4        0.32
# ...                ...            ...                ...         ...
# 1164          employed  south_america                  2        0.30
# 1165           student  south_america                  2        0.44
# 1166           student  north_america                  1        0.02
# 1167           student  north_america                  3        0.02
# 1168     self_employed           asia                  4        0.21
#
#       converted
# 0             0
# 1             1
# 2             1
# 3             0
# 4             1
# ...         ...
# 1164          0
# 1165          0
# 1166          0
# 1167          1
# 1168          0
#
# [1169 rows x 9 columns]

# %%
df_full_train[numerical_without_converted].corr().abs()
# Out:
#                           number_of_courses_viewed  annual_income  \
# number_of_courses_viewed                  1.000000       0.012227
# annual_income                             0.012227       1.000000
# interaction_count                         0.044381       0.011959
# lead_score                                0.009427       0.021273
#
#                           interaction_count  lead_score
# number_of_courses_viewed           0.044381    0.009427
# annual_income                      0.011959    0.021273
# interaction_count                  1.000000    0.025393
# lead_score                         0.025393    1.000000

# %%
# Q3 Mutual information 
# Which of these variables has the biggest mutual information score?

# %%
from sklearn.metrics import mutual_info_score

# %%
m1 = mutual_info_score(df_full_train.converted, df_full_train.lead_source)
m2 = mutual_info_score(df_full_train.converted, df_full_train.industry)
m3 = mutual_info_score(df_full_train.converted, df_full_train.employment_status)
m4 = mutual_info_score(df_full_train.converted, df_full_train.location)

# %%
print("biggest mutual information score")
print("converted - lead_source:\t", round(m1,2))
print("converted - industry:\t\t", round(m2,2))
print("converted - employment_status:\t", round(m3,2))
print("converted - location:\t\t", round(m4,2))
# Out:
# biggest mutual information score
# converted - lead_source:	 0.03
# converted - industry:		 0.01
# converted - employment_status:	 0.01
# converted - location:		 0.0

# %%
# Q4 LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
train_dicts = df_full_train[categorical + numerical].to_dict(orient='records')

# %%
dv = DictVectorizer(sparse=False)
train_dicts = df_full_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dict = y_val_lead_score[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dict)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[122], line 5
#       2 train_dicts = df_full_train[categorical + numerical].to_dict(orient='records')
#       3 X_train = dv.fit_transform(train_dicts)
# ----> 5 val_dict = y_val_lead_score[categorical + numerical].to_dict(orient='records')
#       6 X_val = dv.transform(val_dict)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
dv.fit(train_dicts)
# Out:
# DictVectorizer(sparse=False)

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train_lead_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[123], line 2
#       1 model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
# ----> 2 model.fit(X_train, y_train_lead_score)
#
# File /usr/lib/python3.13/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File /usr/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:1247, in LogisticRegression.fit(self, X, y, sample_weight)
#    1244 else:
#    1245     _dtype = [np.float64, np.float32]
# -> 1247 X, y = validate_data(
#    1248     self,
#    1249     X,
#    1250     y,
#    1251     accept_sparse="csr",
#    1252     dtype=_dtype,
#    1253     order="C",
#    1254     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1255 )
#    1256 check_classification_targets(y)
#    1257 self.classes_ = np.unique(y)
#
# File /usr/lib/python3.13/site-packages/sklearn/utils/validation.py:2971, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2969         y = check_array(y, input_name="y", **check_y_params)
#    2970     else:
# -> 2971         X, y = check_X_y(X, y, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
#
# File /usr/lib/python3.13/site-packages/sklearn/utils/validation.py:1387, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    (...)   1382     input_name="X",
#    1383 )
#    1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1387 check_consistent_length(X, y)
#    1389 return X, y
#
# File /usr/lib/python3.13/site-packages/sklearn/utils/validation.py:473, in check_consistent_length(*arrays)
#     471 lengths = [_num_samples(X) for X in arrays if X is not None]
#     472 if len(set(lengths)) > 1:
# --> 473     raise ValueError(
#     474         "Found input variables with inconsistent numbers of samples: %r"
#     475         % [int(l) for l in lengths]
#     476     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1169, 876]

# %%
dv.get_feature_names_out()

# %%
def logistic_regression(xi):
    score = w0
    
    for j in range(len(w)):
        score = score + xi[j] * w[j]
        
    result = sigmoid(score)
    return result
